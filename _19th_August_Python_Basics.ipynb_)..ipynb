# %%
#to take input from user
x = 27

# %%
y = 95

# %%
x
# Out:
# 27

# %%
y
# Out:
# 95

# %%
#swapping the values of these variable
x,y = y,x

# %%
x
# Out:
# 95

# %%
y
# Out:
# 27

# %%
#to find the area of rectangle

a=15
b=5

# %%
area=a*b

# %%
print(area)
# Out:
# 75

# %%
#converting the temperature
celsius=37
#define farenhite
farenhite=(celsius*1.8+32)

# %%
farenhite
# Out:
# 98.60000000000001

# %%
#string based question
#print the length of the string
string1="garvish"

# %%
print(len(string1))
# Out:
# 7

# %%
#counting the number of vowels in the string
g = 'my name is garvish ramnani'
vowels = 'aeiou'

# %%
count = sum(g.count(vowel) for vowel in vowels)

# %%
print(count)
# Out:
# 8

# %%
#reversing the string
s2 = "garvishramnani"

# %%
s2
# Out:
# 'garvishramnani'

# %%
s2[::]
# Out:
# 'garvishramnani'

# %%
s2[::-1]
# Out:
# 'inanmarhsivrag'

# %%
#program to check whether a string is palindrome or not
s3 = 'radar'
p1 = s3[::-1]

# %%
p1
# Out:
# 'radar'

# %%
#to remove whitespace from a string
g2 = "g  a  r v  i  s h"

# %%
g2.strip()
# Out:
# 'g  a  r v  i  s h'

# %%
g2.trim()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 g2.trim()
#
# AttributeError: 'list' object has no attribute 'trim'
